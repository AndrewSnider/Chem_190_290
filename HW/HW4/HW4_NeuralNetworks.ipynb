# %% [markdown]
# ## HW 4: Neural Networks
#
# In this hw, we will explore how to construct a standard feed-forward neural network using only basic numpy and python functions.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ##  Some good materials for understanding neural networks
# [Neural Networks, Manifolds, and Topology - Colah's blog](http://colah.github.io/posts/2014-03-NN-Manifolds-Topology/)<br>
# [How the backpropagation algorithm works - Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/chap2.html
# )
#
# ## The structure and mathematical forms of neural networks
# ![Neural network](http://colah.github.io/posts/2014-03-NN-Manifolds-Topology/img/example_network.svg)
# <br><br><br>
# ## About activation functions
# ### tanh
# $y=\tanh(x)$
# <br>$y\in(-1,1)$
# <br>$y'=1-y^2$

# %%
x=np.linspace(-5,5,2000)
y=np.tanh(x)
plt.plot(x,y)

# %% [markdown]
# ### sigmoid
# $y={\displaystyle \frac{1}{1+e^{-x}} }$
# <br><br>$y\in(0,1)$
# <br>$y'=y(1-y)$

# %%
x=np.linspace(-5,5,2000)
y=1/(1+np.exp(-x))
plt.plot(x,y)

# %% [markdown]
# ### ReLU
# $y={\displaystyle \begin{equation}
# \begin{cases} &x \:\:\: x\geqslant0 \\
# & 0 \:\:\: x<0
# \end{cases}
# \end{equation}}$
# <br><br>$y\in[0,\infty)$
# <br><br>$y'=\begin{equation}
# \begin{cases}
# & 1\:\:\: x\geqslant0 \\
# & 0\:\:\: x<0
# \end{cases}
# \end{equation}$

# %%
x=np.linspace(-5,5,2000)
y=x*(x>=0)
plt.plot(x,y)

# %% [markdown]
# ### softmax
#
# $y_i=f_i(\vec{x})={\displaystyle \frac{e^{x_i}}{\sum_{j=1}^J e^{x_j}}}$
# <br>$y_i\in[0,1]$
# <br><br>${\displaystyle \frac{\partial y_i}{\partial x_j}=y_i(\delta_{ij}-y_j)}$
#
# <br><br><br><br>

# %% [markdown]
# # Neural Network Notation
#
# Before deriving backpropagation, we define the notation used to describe a feed-forward neural network.
#
# ---
#
# ## Layers
#
# A neural network is composed of **layers of neurons**.
#
# - Input layer: $l = 1$
# - Hidden layers: $l = 2,3,...,L-1$
# - Output layer: $l = L$
#
# Where:
#
# - $L$ = total number of layers in the network.
#
# ---
#
# ## Activations
#
# The **activation** of neuron $j$ in layer $l$ is written as
#
# $
# a_j^l
# $
#
# This represents the **output value of that neuron after applying the activation function**.
#
# The activations for an entire layer can be written as a vector:
#
# $
# \mathbf{a}^l
# $
#
# For the **input layer**
#
# $
# \mathbf{a}^1 = \mathbf{x}
# $
#
# which is simply the input data.
#
# ---
#
# ## Weights
#
# Connections between neurons are represented by **weights**.
#
# $w_{jk}^l$
#
# Where:
#
# - $w_{jk}^l$ is the weight connecting neuron $k$ in layer $l-1$ to neuron $j$ in layer $l$.
#
# All weights for a layer can be written as a matrix:
#
# $
# \mathbf{W}^l
# $
#
# ---
#
# ## Bias
#
# Each neuron also has a **bias term**
#
# $
# b_j^l
# $
#
# The vector of biases for a layer is
#
# $
# \mathbf{b}^l
# $
#
# ---
#
# ## Weighted Input
#
# Before applying the activation function, each neuron computes a **weighted input**
#
# $
# z_j^l
# $
#
# $
# z_j^l = \sum_k w_{jk}^l a_k^{l-1} + b_j^l
# $
#
# In vector form:
#
# $
# \mathbf{z}^l = \mathbf{W}^l \mathbf{a}^{l-1} + \mathbf{b}^l
# $
#
# ---
#
# ## Activation Function
#
# The neuron output is obtained by applying an **activation function**
#
# $
# a_j^l = \sigma(z_j^l)
# $
#
# or in vector form
#
# $
# \mathbf{a}^l = \sigma(\mathbf{z}^l)
# $
#
# Examples of activation functions include:
#
# - Sigmoid
# - Tanh
# - ReLU
#
# ---
#
# ## Error Term
#
# During backpropagation we define an **error signal**
#
# $
# \delta_j^l
# $
#
# which measures how much neuron $j$ in layer $l$ contributes to the total loss.
#
# Backpropagation computes these error terms starting from the output layer and propagating them backward through the network.
#
# ---
#
# ## Summary of the Forward Pass
#
# For each layer $l = 2 ... L$:
#
# $
# \mathbf{z}^l = \mathbf{W}^l \mathbf{a}^{l-1} + \mathbf{b}^l
# $
#
# $
# \mathbf{a}^l = \sigma(\mathbf{z}^l)
# $
#
# Training the network consists of adjusting $W$ and $b$ to minimize the loss function.

# %% [markdown]
# ## Visualized for a single neuron
# ![Neuron](https://i.imgur.com/ixThGac.png)
#
# ### keep in mind that the "inputs" in higher L layers will be the activation values from previous layers

# %% [markdown]
# # Understanding Backpropagation
#
# Backpropagation is the algorithm used to compute **gradients of the loss function with respect to the network parameters** so they can be updated using gradient descent.
#
# Reference:
# http://neuralnetworksanddeeplearning.com/chap2.html
#
# ---
#
# # Step 1: Loss Function
#
# We begin with the **Mean Squared Error (MSE)** loss:
#
# $$
# C_{MSE} =
# \frac{1}{2n}\lVert a^L - y \rVert^2
# $$
#
# Where:
#
# - $a^L$ = output activations of the final layer
# - $y$ = reference values
# - $n$ = number of samples
# - $C$ = cost (loss) function
#
# The goal of training is to **minimize this cost**.
#
# ---
#
# # Step 2: Output Layer Error
#
# The error term for the **final layer** is
#
# $$
# \delta^L = \frac{\partial C}{\partial z^L}
# = \nabla_a C \odot \sigma'(z^L)
# $$
#
# Where:
#
# - $z^L$ = weighted input to the final layer
# - $\sigma'(z^L)$ = derivative of the activation function
# - $\odot$ = element-wise multiplication
#
# Interpretation:
#
# This equation tells us **how sensitive the loss is to changes in the final layer inputs**.
#
# ---
#
# # Step 3: Propagating Error Backwards
#
# For hidden layers, the error is computed recursively:
#
# $$
# \delta^l =
# \frac{\partial C}{\partial z^l}
# =
# \left((w^{l+1})^T \delta^{l+1}\right)
# \odot
# \sigma'(z^l)
# $$
#
# Meaning:
#
# 1. The error from the **next layer** is propagated backward.
# 2. It is multiplied by the **transpose of the weights**.
# 3. It is scaled by the **activation derivative**.
#
# This step is the core of **backpropagation**.
#
# ---
#
# # Step 4: Gradient of Biases
#
# The gradient with respect to the biases is simply:
#
# $$
# \frac{\partial C}{\partial b^l} = \delta^l
# $$
#
# Interpretation:
#
# Each neuron’s bias affects the loss directly through the **error term**.
#
# ---
#
# # Step 5: Gradient of Weights
#
# The gradient with respect to the weights is
#
# $$
# \frac{\partial C}{\partial w^l}
# =
# (\delta^l)^T a^{l-1}
# $$
#
# Where:
#
# - $a^{l-1}$ = activations from the **previous layer**
#
# Interpretation:
#
# The weight update depends on:
#
# - how much **error the neuron has** ($\delta^l$)
# - how strongly the **previous neuron was activated**
#
# ---
#
# # Summary of Backpropagation Flow
#
# Forward Pass:
#
# $$
# x \rightarrow z^l \rightarrow a^l
# $$
#
# Backward Pass:
#
# $$
# C \rightarrow \delta^L \rightarrow \delta^{L-1} \rightarrow ... \rightarrow \delta^1
# $$
#
# Gradients computed:
#
# - $ \frac{\partial C}{\partial w^l} $
# - $ \frac{\partial C}{\partial b^l} $
#
# These gradients are used in **gradient descent** to update parameters.
#
# ---
#
# # Question 1: Implementing a Neural Network Class
#
# Finish the `init_weights` method by adding randomly sampled **weights** and **biases** using:
#
# ```python
# np.random.random()

# %%
import numpy as np

class NN():
    def __init__(self,architecture,learning_rate=0.01,activation=lambda x:x):
        '''The architecture is a list, with each element specifying the number of nodes in each layer'''
        self.arch=architecture
        self.activation=activation
        self.lr=learning_rate
        self.ffcount=len(self.arch)-1
        self.initialized=False
        
    def init_weights(self):
        self.weights=[]
        self.biases=[]
        for n in range(self.ffcount):
            prev_layer_neurons=self.arch[n]
            current_layer_neurons=self.arch[n+1]
            self.weights.append(...) # Add code to initialize weights here
            self.biases.append(...)  # Add code to initialize biases here
        self.initialized=True
        
    def feed_forward(self,x):
        if self.initialized:
            a_n=np.array(x)
            z_s=[]
            a_s=[a_n]
            for n in range(self.ffcount):
                z_n=self.weights[n].dot(a_n)+self.biases[n]
                a_n=self.activation(z_n)
                z_s.append(z_n)
                a_s.append(a_n)
            self.z_s=z_s
            self.a_s=a_s
            self.pred=a_n
            return a_n
        else:
            print("Please initialize the weights first!")
            
    def calc_error(self,y,activation_grad):
        y=np.array(y)
        errors=[(self.pred-y)*activation_grad(self.z_s[-1])]
        for n in range(self.ffcount-1):
            errors.append(self.weights[-n-1].T.dot(errors[-1])*activation_grad(self.z_s[-n-2]))
        errors.reverse()
        self.errors=errors
        return errors
            
    def calc_grad(self):
        weights_grad=[]
        for n in range(self.ffcount):
            weights_grad.append(self.errors[n].reshape(-1,1).dot(self.a_s[n].reshape(1,-1)))
        biases_grad=self.errors
        self.weights_grad=weights_grad
        self.bias_grad=biases_grad
        return weights_grad,biases_grad
    
    def back_prop(self):
        for n in range(self.ffcount):
            self.weights[n]=self.weights[n]-self.lr*self.weights_grad[n]
            self.biases[n]=self.biases[n]-self.lr*self.bias_grad[n]
            
    def fit(self,x,y,activation_grad):
        self.feed_forward(x)
        self.calc_error(y,activation_grad)
        self.calc_grad()
        self.back_prop()
        
    def predict(self,x):
        return self.feed_forward(x)

# %% [markdown]
# ## Question 2: Activation Functions
#
# Implement the tanh activation function and it's respective derivative as setup below so that we can use them in our NN model.

# %%
def tanh(x):
    return 

def tanh_grad(x):
    return

# %% [markdown]
# ### Test Your Work
# The cell below should run without errors.

# %%
nn=NN([6,2,2],activation=tanh)
nn.init_weights()
print("Initialized prediction:",nn.predict([-1,1,-1,-1,1,-1]))
nn.fit([-1,1,-1,-1,1,-1],[-1,-1],tanh_grad)
print("Error in nodes:",nn.errors)
print("Prediction after fitting once:",nn.predict([-1,1,-1,-1,1,-1]))

# %% [markdown]
# ## Question 3: Regularization, L1 and L2
# <br>
#
# $$C=\frac{1}{2n}\lVert a^L-y^{GT}\rVert^2+\lambda\sum\lVert \theta_i\rVert ^p$$
#
# Copy your working `NN()` class code from the previous question (apart from the __init__ section )and use it as a starting point for the `NN_reg()` class setup below. Your goal will be to modify the `calc_error()` method such that the 'error' variable in that method includeds either L1 (Lasso) or L2 (Regression) depending on user input.
#
# **Hint: You can use the .flatten() method on an array of weights in a given layer to get everything into a 1d array**

# %%
class NN_reg():
    def __init__(self,architecture,regularization=None,learning_rate=0.01,activation=lambda x:x,reg_lambda=0.1):
        '''The architecture is a list, with each element specifying the number of nodes in each layer'''
        self.arch=architecture
        self.activation=activation
        self.lr=learning_rate
        self.ffcount=len(self.arch)-1
        self.regularization=regularization
        self.reg_lambda=reg_lambda
        self.initialized=False
...

# %% [markdown]
# ### Question 4: Testing The Fitting Proccess
#
# Using your modified `NN_reg()` code and the one off training example above, create a new model and train it using the same single data point for 1000 epochs. Save the model predictions and relative errors at each epoch, plotting the results in a way that demonstrates the progressive improvement of the model fit.

# %%
nn=NN_reg([6,2,2],'L2',activation=tanh)
nn.init_weights()
print("Initialized prediction:",nn.predict([-1,1,-1,-1,1,-1]))

...

# %% [markdown]
# ## Some guidelines for designing a reasonable NN
# * The first hidden layer should usually expand the dimension
# * The following hidden layers should gradually contract (form funnel shape network)
# * Dimension change between layers should not be crazy
# * Notice the total number of parameters - ideally less than 1/10 of number of training examples
# * Should start from shallow networks, if both training error/ test error are high, then consider increasing network complexity
# * Usually suggested to use ReLU activation for hidden layers (can also try tanh)
# * Choose the right type of activation for the output layer!
