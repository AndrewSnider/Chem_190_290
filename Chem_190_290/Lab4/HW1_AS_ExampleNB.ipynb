# %% [markdown]
# ## JUST AN EXAMPLE OF HOW TO FORMAT THE CODE FOR HW1, HIGHLY SUGGEST COPYING PARTS INTO YOUR OWN PERSONAL NOTEBOOK AS NEEDED, DON'T RELY ON THIS NOTEBOOK AS A TEMPLATE

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# ### Data Loading Section

# %%
### Loading in data

# data for plot a
b3lyp_krr_tcf = np.loadtxt('b3lyp_krr_tcf.txt',usecols=1)  # orange line
b3lyp_krr_tcf = b3lyp_krr_tcf / (0.2081943 * 0.2081943 * 1000)

new_weighted_neutral_tcf = np.loadtxt('new_weighted_neutral_tcf.txt',usecols=1) # dotted blue line
...


# data for plot b
molecular_dipole_single_tcf = np.loadtxt('molecular_dipole_single_tcf.txt',usecols=1) # orange line
...

# data for plot c
...

# x axis data for whole plot
x_data_time = np.loadtxt('b3lyp_krr_tcf.txt',usecols=0)

# %% [markdown]
# ### Plotting Section

# %%
# Load in data
#################################################
x = ...
y = ...
#################################################


# Create Triple Stacked Subplot
#################################################
fig, axs = plt.subplots(3,sharex = True)
#################################################

# fig = full figure variables
# axs[0] = top panel plot (a) variables
# axs[1] = middle panel plot (b) variables
# axs[2] = bottom panel plot (c) variables
# example inset for plot a define below


# panel (a) main plot
#################################################
axs[0].plot(x, y,label='y',color = '#FCB131')
axs[0].plot(x, y_squared,label='y_squared',color = 'green')
axs[0].set(ylabel='Top Subplot')
axs[0].text(0.5, -0.5, 'Random text')
axs[0].set_xlabel(r'$t$ (ps)') #  <- only one subplot has x-axis label since they have sharex = True
#################################################



# panel (b) main plot
#################################################
axs[1].plot(...)
...
#################################################




# panel (c) main plot
#################################################
axs[2].plot(...)
...
#################################################



# panel (a) inset
#################################################
left, bottom, width, height = [0.50, 0.74, 0.36, 0.125] # play around with values to get right inset size and position
axins_a = fig.add_axes([left, bottom, width, height]) # can assign inset axs to any variable name
axins_a.plot(...)
axins_a.legend(frameon=False)

#################################################
