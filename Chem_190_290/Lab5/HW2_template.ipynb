# %% [markdown]
# # HW 2
#
# The goal of HW2 is to generate 16 radial atom-centered symmetry functions (ACSFs) for the central atom in a water cluster. This notebook is designed as a basic starting template if you would like to use one.

# %% [markdown]
# #### Load in libraries

# %%
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
import math

# %% [markdown]
# #### Load in data
#
# The data for this HW can all be found in the `HW2.pdf` document, but are also available as raw data files in the `Lab5` folder on catourses.
#
# `water_cluster.xyz` - XYZ coordinates for the 3 water molecules, first entry is the central Oxygen atom
#
# `ACSF_params.txt` - The 16 ACSF parameters needed to generate the 16 radial ACSFs for the assignment
#
# Pandas, Numpy, and many other libraries work for loading in the data. Make sure look at the data after loading it to make sure it's in the format you want.

# %%
xyz = ...
xyz

# %%
params = ...
params

# %% [markdown]
# #### Defining intermediate functions
#
# It's entirely possible to complete this HW without using a single user-defined function. However, for problems like this one that involve somewhat complicated math expressions and data manipulation,

# %%
def calculate_distance_3d(point1, point2):
    ...
    return distance

def fc(Rij,Rc=12.0):
    ...
    return output

def rad_ACSF(i,eta,Rs):
    ...
    return gauss

# %% [markdown]
# #### Generating the final output
#
# Using (or not using) intermediate functions defined above, generate the 16 radial ACSFs for the central oxygen atom and store them in an array called `central_O_ACSFs`
#
# After that report the norm of the array using `np.linalg.norm`

# %%
central_O_ACSFs = ...


norm = np.linalg.norm(central_O_ACSFs)
print(f'Norm of ACSFs for the central oxygen atom is {norm:.3f}')
